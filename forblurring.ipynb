# %%
# This is my main code for adding the blurring on the images, I used it in all the datasets
#located in datasets blurring

# %%
from PIL import Image, ImageFilter
import os

def apply_custom_blur(image_path, output_path, blur_radius=2):
    """
    Apply a custom blur to an image and save it to the output path.
    
    :param image_path: Path to the input image.
    :param output_path: Path to save the blurred image.
    :param blur_radius: Radius of the blur (higher values = more blur).
    """
    # Open the image
    image = Image.open(image_path)
    
    # Apply Gaussian blur
    blurred_image = image.filter(ImageFilter.GaussianBlur(radius=blur_radius))
    
    # Save the blurred image
    blurred_image.save(output_path)
    print(f"Blurred image saved to {output_path}")

def blur_images_in_folder(folder_path, output_folder_name, blur_radius=2):
    """
    Apply custom blur to all images in a folder and save them to a new output folder.
    
    :param folder_path: Path to the folder containing images.
    :param output_folder_name: Name of the new folder to save blurred images.
    :param blur_radius: Radius of the blur (higher values = more blur).
    """
    # Create the output folder path
    output_folder = os.path.join(folder_path, output_folder_name)
    
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        print(f"Created output folder: {output_folder}")
    
    # Loop through all files in the folder
    for filename in os.listdir(folder_path):
        # Check if the file is an image
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.tiff')):
            # Construct full file paths
            input_image_path = os.path.join(folder_path, filename)
            output_image_path = os.path.join(output_folder, filename)
            
            # Apply blur and save the image
            apply_custom_blur(input_image_path, output_image_path, blur_radius)

# Example usage
folder_path = "/home/esidserver/datasets/1-original-dataset_split5/test/Culex"  # Your folder path
output_folder_name = "/home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex"  # Name of the new folder for output images
blur_radius = 3  # Adjust the blur intensity

blur_images_in_folder(folder_path, output_folder_name, blur_radius)
# Out:
# Created output folder: /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_001_02_lab_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_025_03_lab_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_004_03_lab_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (973)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (102)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (4)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (296)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1080)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_023_01_lab_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (291)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (480)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (413)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (550)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1187)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (357)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (26)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_021_01_lab_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (145)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (734)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (420)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1096)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (704)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (797)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1080)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (557)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1146)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (797)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (921)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_010_03_lab_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_002_04_lab_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1212)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (870)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_027_04_lab_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_014_04_lab_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1294)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (276)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (174)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1076)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (347)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (223)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (313)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (401)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (977)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (260)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_044_02_lab_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (601)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (542)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_031_03_lab_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_001_03_lab_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1330)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1197)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_023_01_lab_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (687)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (504)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1246)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_021_01_lab_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (413)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (33)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_034_02_lab_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_018_02_lab_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1330)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1206)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (480)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_034_04_lab_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_029_03_lab_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_042_02_lab_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1206)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1339)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_034_04_lab_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (542)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_008_01_lab_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (102)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (223)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (409)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1248)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1076)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1080)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1187)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (220)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1117)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (123)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (413)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1139)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (776)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (950)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1372)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (91)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (435)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1451)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (401)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1248)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1139)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (269)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_016_04_lab_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (977)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1128)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (687)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (802)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (383)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (725)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (59)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (148)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (69)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (734)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_012_02_lab_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (754)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1248)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (39)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (223)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (409)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (230)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (39)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1339)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (518)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (925)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (220)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_007_01_lab_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (33)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (701)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_042_02_lab_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (951)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1244)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (542)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_005_04_lab_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_027_01_lab_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (420)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_012_02_lab_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (376)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1096)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (26)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (230)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1394)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (527)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (220)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (936)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (980)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (145)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1351)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (53)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (920)_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (589)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_021_01_lab_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1132)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (347)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_100x_029_03_lab_aug3.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (260)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus_40x_034_02_lab_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (429)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (4)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1451)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (951)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (601)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1364)_orig.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1362)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1364)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (174)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1402)_aug1.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (615)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (564)_aug2.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (241)_aug5.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 (1466)_aug4.jpg
# Blurred image saved to /home/esidserver/datasets/1-original-dataset_split5/test-blur/Culex/CulexQuinquefasciatus-InfinixS5 